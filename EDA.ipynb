# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
original_df = pd.read_csv("listings.csv")
original_df['neighbourhood'].isnull().sum()
# Out:
# 3372

# %%
df = pd.read_csv("listing_review_tfidf_v6_property_500_final.csv")

# %%
sns.set(style='darkgrid')

# %%
sns.relplot(x='reviews_per_month',y='review_scores_rating',hue='host_is_superhost',data=df)

# %%
sns.relplot(x='reviews_per_month',y='review_scores_rating',hue='has_availability',data=df)

# %%
sns.scatterplot(x='beds',y='review_scores_rating',hue='has_availability',data=df)
# Out:
# <AxesSubplot: xlabel='beds', ylabel='review_scores_rating'>

# %%
# df['minimum_nights'] = pd.qcut(df['minimum_nights'],3)

# %%
sns.relplot(x='minimum_nights',y='review_scores_rating',hue='instant_bookable',data=df)

# %%
sns.lineplot(x='host_response_time',y='review_scores_rating',data=original_df)
# Out:
# <AxesSubplot: xlabel='host_response_time', ylabel='review_scores_rating'>

# %%
sns.barplot(x='beds',y='review_scores_rating',data=original_df)
# Out:
# <AxesSubplot: xlabel='beds', ylabel='review_scores_rating'>

# %%
sns.relplot(x='accommodates',y='review_scores_rating',hue='host_identity_verified_int',data=df)

# %%
sns.relplot(x='reviews_per_month',y='review_scores_accuracy',hue='host_is_superhost',data=df)

# %%
sns.relplot(x='accommodates',y='review_scores_value',hue='host_has_profile_pic_int',data=df)

# %%
sns.relplot(x='number_of_reviews',y='review_scores_rating',hue='host_is_superhost',data=df)
